# %% [markdown]
# # Deep Learning 2023 - Assignment 1
#
# Designed by Marko Savic (marko.savic@oulu.fi)

# %% [markdown]
# ## Outline (15 points)
# #### In this assignment, you will learn:
# * How to load data and create a train/test split.
# * How to build your own Pytorch model for simple linear regression problem.
# * Training the model with gradient descent algorithm in Pytorch.
#
# #### Environment
# Python 3 + Pytorch (>=1.3), Jupyter notebook.<br>
# Other libraries should be installed correctly such as numpy, matplotlib, *etc*., according to the dependencies of the assignment. Check slides of lecture 3 on how to set up an environment with the right dependencies<br>
# If you haven’t installed Pytorch and Jupyter notebook in your computer, an alternative environment to finish the assignment is CSC notebook: [`https://notebooks.csc.fi/`](https://notebooks.csc.fi/) -> log in with HaKa using your university account -> Jupyter Machine Learning.
# Also, google colab is available through your google university account (instruction in patio https://patio.oulu.fi/en/services-and-instructions/it-services/information-systems/google-workspace-education). Computer room TS135 contains computers with GPUs that you can utilise as well.
#
# We will give 2 weeks for each assignment and more for the final project. So it may happen where the new assignment is published before the deadline of the previous assignment. The answer will be released after the deadline.
# Please also put your name and student number (if have) in the file name of the returned assignments.(DL2023_assign1_Name_Surname_studentnumber.ipynb)
#
# #### Database
# * Diabetes dataset
#
# #### Hints
# * To find the place where you have to insert your solution, hit Crtl + F and search for **TODO:** . You are not supposed to modify the codes from other parts.
# * Be careful with the shape of the weights, gradient, .. of your tensor in your implementation. Double check and make sure the shapes fit for computation, especially matrix multiplication.

# %% [markdown]
# ## Part 1. Load dataset and split into training and testing sets
#
# Suppose we observe a set of n real-valued input variables x = $\{x_n\}$ and wish to use this observation to predict
# the value of a real-valued target variable $y$. In the tutorial we considered artifical examples with synthetic data. In this exercise we will consider a simple dataset that is suitable for linear regression.
#
# We will take the Diabetes dataset which contains ten baseline variables: age, sex, body mass index, average blood pressure, and six blood serum measurements that were obtained for each of n = 442 diabetes patients, as well as the response of interest, a quantitative measure of disease progression one year after baseline. Assuming a linear model is a good representation of this phenomenon we will try predict diabetes disease progression.
#
# The dataset is already preprocessed and available with the scikit-learn library. Firstly we will import the entire dataset of 442 instances, and then split the data into training and testing sets. In this case we choose a five fold split, meaning we will use 20% of the data for testing and 80% for training.
#
# Please create the required training and testing data below and plot the relationship between the feature 'bmi' and the target. Since we have 10 different features, we will only pick 'bmi' for plotting.

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
import numpy as np
from sklearn.datasets import load_diabetes

diabetes_db  = load_diabetes()
print(diabetes_db.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
from sklearn.model_selection import train_test_split
# TODO: (3 points, details are given below): 

# get the relevant data from the diabetes_db dictionary and assign them to the Tensors x (feature variables) and y (target)  (1 point)
x = torch.tensor(diabetes_db.data, dtype=torch.float32)
y = torch.tensor(diabetes_db.target, dtype=torch.float32).view(-1, 1)


# divide the data in a train set (80% of the data) and test set (20% of the data). Resulting in x_train, x_test, y_train, y_test (1 point)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# plot the third feature 'bmi' in relationship with the target y. Train and test data should be in a single figure with two different showing styles (1 point)
plt.figure(figsize=(15, 8) )
plt.scatter(x_train[:, 2], y_train, s=5)
plt.scatter(x_test[:, 2], y_test, color='red', s=50)
plt.show()

# %% [markdown]
# ## Part 2. Solving the linear regression problem in Pytorch using Gradient Descent Algorithm
# Congratulations you have prepared the data correctly! Now we will move onto creating our model and training it.

# %% [markdown]
# ### 2.1 Model
# In this part, you will define your own model class. To do that, you have to remember the following rules:
# 1. The model class should be inherited from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module);
# 2. Re-write the **\_\_init\_\_** function and the **forward** function;
# 3. In the **\_\_init\_\_** function, you should always call the parent's **\_\_init\_\_** function first.
#
# To make it simpler, since we are using a linear function to approximate the phenomenon that generated the data, our function will be:
#
# \begin{align*}
# y = w^T x + b
# \end{align*}
#
# Therefore, in the model, we need to set 2 parameters: $w$, $b$

# %%
# TODO (3.5 points, details are given below)
import torch.nn as nn


# define a class (0.5) + write the __init__ function (1.5 point) + write the forward function (1.5 points)

# In the LinearRegressionModel class, modify the __init__ function
class LinearRegressionModel(nn.Module):
    def __init__(self, input_size):
        super(LinearRegressionModel, self).__init__()
        self.w = nn.Parameter(torch.randn(input_size, 1, requires_grad=True))  # Weight
        self.b = nn.Parameter(torch.randn(1, 1, requires_grad=True))  # Bias

    def forward(self, x):
        y_pred = torch.matmul(x, self.w) + self.b
        return y_pred

# %% [markdown]
# ### 2.2 Training
# Here, you will train your model based on the training data and evaluate the model on testing data.
# 1. Set proper number of iterations and learning rate.
# 2. Remember to use a proper optimizer (you may have many choices: Adam, SGD, RMSprop, ... please find the detailed information in https://pytorch.org/docs/stable/optim.html and know how to use them).
# 3. In order to train the model, a loss function should be defined:
# \begin{align*}
# loss = \frac{1}{N}\sum_{i=1}^{N}|f_i - y_i|,
# \end{align*}
# where, $f_i$ is the output of the model and $N$ is the number of training data pairs.
# 4. The model must be trained only using training data.
# 5. Remember to clear the old gradients of parameters before a new backward propagation.
# 6. In every certain number of iterations, print the training loss, and the testing loss.
# 7. Meanwhile, please track the training loss and the testing loss in each iteration. Once the training is done, the curves of losses should be plotted (two curves are drawn in the same figure, where x axis indicates iterations and y axis indicates the losses).
# 8. Lastly, draw all the training data, testing data and the curve of the trained model in the same figure (use different showing styles to distinguish them).

# %%
# TODO (8.5 points, details are given below)

# Make a instance of the model class (0.5 point)
model = LinearRegressionModel(input_size=x.shape[1])
# create an optimizer, set a workable learing rate (0.5 point + 0.5 point)
optimizer = torch.optim.Adam(model.parameters(), lr=0.1 )
criterion = nn.L1Loss()
training_losses = []
testing_losses = []

n_itr = 10000

for i in range(n_itr):
    # Train
    # forward propagation 
    model.train() # change model to train mode
    
    # calculate the output of model (0.5 point)
    output = model(x_train)
    # calculate loss according to the above equation (0.5 point)
    #loss = torch.mean(torch.abs(output - y_train))
    loss = nn.L1Loss()(output, y_train)
    
    training_losses.append(loss.item())
    
    
    # backward propagation 
    # clear old gradients (0.5)
    optimizer.zero_grad()
    
    # calculate gradients of parameters (1 point)
    loss.backward()
    
    # gradient descent algorithm (1 point)
    optimizer.step()
    
    # Evaluate, calculate the testing loss (0.5 point)
    model.eval() # change model to eval mode
    with torch.no_grad():
        test_output = model(x_test)
        #test_loss = torch.mean(torch.abs(test_output - y_test))
        test_loss = nn.L1Loss()(test_output, y_test)
    
    testing_losses.append(test_loss.item())

    # print intermediate losses for certain iterations (1 point)
    if i % 100 == 1: 
        print('Iteration: %04d | Training loss: %f | Testing loss: %f' % \
              (i, loss.data, test_loss.data))
# Out:
# Iteration: 0001 | Training loss: 153.391983 | Testing loss: 155.806320
# Iteration: 0101 | Training loss: 143.301239 | Testing loss: 146.166351
# Iteration: 0201 | Training loss: 133.210449 | Testing loss: 136.526352
# Iteration: 0301 | Training loss: 123.181358 | Testing loss: 126.899261
# Iteration: 0401 | Training loss: 113.397133 | Testing loss: 117.254501
# Iteration: 0501 | Training loss: 103.931061 | Testing loss: 107.663094
# Iteration: 0601 | Training loss: 95.028015 | Testing loss: 98.415390
# Iteration: 0701 | Training loss: 86.906151 | Testing loss: 89.993622
# Iteration: 0801 | Training loss: 79.617455 | Testing loss: 83.022224
# Iteration: 0901 | Training loss: 73.020729 | Testing loss: 76.829376
# Iteration: 1001 | Training loss: 67.234749 | Testing loss: 71.328285
# Iteration: 1101 | Training loss: 62.379436 | Testing loss: 66.718819
# Iteration: 1201 | Training loss: 58.822552 | Testing loss: 62.888435
# Iteration: 1301 | Training loss: 56.338139 | Testing loss: 60.007725
# Iteration: 1401 | Training loss: 54.045391 | Testing loss: 57.228443
# Iteration: 1501 | Training loss: 52.005623 | Testing loss: 54.792690
# Iteration: 1601 | Training loss: 50.262360 | Testing loss: 52.650036
# Iteration: 1701 | Training loss: 48.960938 | Testing loss: 51.073997
# Iteration: 1801 | Training loss: 47.938774 | Testing loss: 49.711288
# Iteration: 1901 | Training loss: 47.102180 | Testing loss: 48.604176
# Iteration: 2001 | Training loss: 46.376942 | Testing loss: 47.575756
# Iteration: 2101 | Training loss: 45.818645 | Testing loss: 46.889927
# Iteration: 2201 | Training loss: 45.360607 | Testing loss: 46.377792
# Iteration: 2301 | Training loss: 45.002037 | Testing loss: 45.983212
# Iteration: 2401 | Training loss: 44.721222 | Testing loss: 45.673317
# Iteration: 2501 | Training loss: 44.505177 | Testing loss: 45.433491
# Iteration: 2601 | Training loss: 44.319443 | Testing loss: 45.246651
# Iteration: 2701 | Training loss: 44.140102 | Testing loss: 45.087925
# Iteration: 2801 | Training loss: 44.004581 | Testing loss: 45.023804
# Iteration: 2901 | Training loss: 43.903999 | Testing loss: 45.011436
# Iteration: 3001 | Training loss: 43.853462 | Testing loss: 44.957462
# Iteration: 3101 | Training loss: 43.802933 | Testing loss: 44.891869
# Iteration: 3201 | Training loss: 43.751644 | Testing loss: 44.832363
# Iteration: 3301 | Training loss: 43.699821 | Testing loss: 44.781040
# Iteration: 3401 | Training loss: 43.646202 | Testing loss: 44.730408
# Iteration: 3501 | Training loss: 43.601852 | Testing loss: 44.658890
# Iteration: 3601 | Training loss: 43.561329 | Testing loss: 44.574139
# Iteration: 3701 | Training loss: 43.528339 | Testing loss: 44.477150
# Iteration: 3801 | Training loss: 43.499020 | Testing loss: 44.426018
# Iteration: 3901 | Training loss: 43.469330 | Testing loss: 44.366936
# Iteration: 4001 | Training loss: 43.440941 | Testing loss: 44.367809
# Iteration: 4101 | Training loss: 43.411640 | Testing loss: 44.378891
# Iteration: 4201 | Training loss: 43.391045 | Testing loss: 44.390591
# Iteration: 4301 | Training loss: 43.372185 | Testing loss: 44.367565
# Iteration: 4401 | Training loss: 43.352711 | Testing loss: 44.348701
# Iteration: 4501 | Training loss: 43.334301 | Testing loss: 44.379742
# Iteration: 4601 | Training loss: 43.315590 | Testing loss: 44.421528
# Iteration: 4701 | Training loss: 43.299767 | Testing loss: 44.465622
# Iteration: 4801 | Training loss: 43.283661 | Testing loss: 44.479137
# Iteration: 4901 | Training loss: 43.269569 | Testing loss: 44.473011
# Iteration: 5001 | Training loss: 43.256207 | Testing loss: 44.489468
# Iteration: 5101 | Training loss: 43.245472 | Testing loss: 44.501999
# Iteration: 5201 | Training loss: 43.238060 | Testing loss: 44.514778
# Iteration: 5301 | Training loss: 43.233578 | Testing loss: 44.544594
# Iteration: 5401 | Training loss: 43.229366 | Testing loss: 44.555191
# Iteration: 5501 | Training loss: 43.225220 | Testing loss: 44.563210
# Iteration: 5601 | Training loss: 43.221035 | Testing loss: 44.567535
# Iteration: 5701 | Training loss: 43.216805 | Testing loss: 44.573498
# Iteration: 5801 | Training loss: 43.213100 | Testing loss: 44.580814
# Iteration: 5901 | Training loss: 43.209412 | Testing loss: 44.589745
# Iteration: 6001 | Training loss: 43.205643 | Testing loss: 44.598705
# Iteration: 6101 | Training loss: 43.201721 | Testing loss: 44.607014
# Iteration: 6201 | Training loss: 43.197803 | Testing loss: 44.616398
# Iteration: 6301 | Training loss: 43.193829 | Testing loss: 44.627045
# Iteration: 6401 | Training loss: 43.189835 | Testing loss: 44.636929
# Iteration: 6501 | Training loss: 43.186668 | Testing loss: 44.643234
# Iteration: 6601 | Training loss: 43.183781 | Testing loss: 44.652519
# Iteration: 6701 | Training loss: 43.181301 | Testing loss: 44.655296
# Iteration: 6801 | Training loss: 43.178913 | Testing loss: 44.658287
# Iteration: 6901 | Training loss: 43.176575 | Testing loss: 44.658409
# Iteration: 7001 | Training loss: 43.174328 | Testing loss: 44.657909
# Iteration: 7101 | Training loss: 43.171974 | Testing loss: 44.658714
# Iteration: 7201 | Training loss: 43.169685 | Testing loss: 44.659496
# Iteration: 7301 | Training loss: 43.167416 | Testing loss: 44.659836
# Iteration: 7401 | Training loss: 43.165508 | Testing loss: 44.664757
# Iteration: 7501 | Training loss: 43.163292 | Testing loss: 44.667984
# Iteration: 7601 | Training loss: 43.161236 | Testing loss: 44.675327
# Iteration: 7701 | Training loss: 43.159088 | Testing loss: 44.677711
# Iteration: 7801 | Training loss: 43.156902 | Testing loss: 44.684067
# Iteration: 7901 | Training loss: 43.155281 | Testing loss: 44.688435
# Iteration: 8001 | Training loss: 43.153927 | Testing loss: 44.690506
# Iteration: 8101 | Training loss: 43.152626 | Testing loss: 44.689457
# Iteration: 8201 | Training loss: 43.151482 | Testing loss: 44.688797
# Iteration: 8301 | Training loss: 43.149998 | Testing loss: 44.686138
# Iteration: 8401 | Training loss: 43.148773 | Testing loss: 44.687477
# Iteration: 8501 | Training loss: 43.147400 | Testing loss: 44.684910
# Iteration: 8601 | Training loss: 43.146107 | Testing loss: 44.685951
# Iteration: 8701 | Training loss: 43.144875 | Testing loss: 44.682098
# Iteration: 8801 | Training loss: 43.143520 | Testing loss: 44.679462
# Iteration: 8901 | Training loss: 43.142239 | Testing loss: 44.679050
# Iteration: 9001 | Training loss: 43.140972 | Testing loss: 44.681679
# Iteration: 9101 | Training loss: 43.139637 | Testing loss: 44.679447
# Iteration: 9201 | Training loss: 43.138386 | Testing loss: 44.676254
# Iteration: 9301 | Training loss: 43.137020 | Testing loss: 44.677731
# Iteration: 9401 | Training loss: 43.135731 | Testing loss: 44.677658
# Iteration: 9501 | Training loss: 43.134438 | Testing loss: 44.676651
# Iteration: 9601 | Training loss: 43.133026 | Testing loss: 44.676456
# Iteration: 9701 | Training loss: 43.131752 | Testing loss: 44.672352
# Iteration: 9801 | Training loss: 43.130333 | Testing loss: 44.672489
# Iteration: 9901 | Training loss: 43.128994 | Testing loss: 44.674049

# %%
# plot the traing losses (0.5 point) and testing losses (0.5 point)
# Plot the training and testing losses
plt.figure()
plt.plot(training_losses, label='Training Loss')
plt.plot(testing_losses, label='Testing Loss', color='orange')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Testing Loss')
plt.show()

# %%
# As our model contains a 10 dimensionsional input we will only plot the relationship between the third variable 'bmi' and the target.
# Again plot the train and test data (from Part1), and add a line where the slope and axis intercept are taken from the model parameters w and b
# (1 point)


# Extract the 'bmi' feature from the training and testing data
bmi_train = x_train[:, 2].detach().numpy()
bmi_test = x_test[:, 2].detach().numpy()

# Calculate the predicted values using the trained model
y_pred_train = model(x_train).detach().numpy()
y_pred_test = model(x_test).detach().numpy()

# Extract the weights (slope) and bias from the trained model
slope = model.w.detach().numpy()[0, 0]  
intercept = model.b.detach().numpy()[0, 0] 

# Plot the 'bmi' feature vs. target for the training and testing data
plt.figure(figsize=(15, 8))
plt.scatter(bmi_train, y_train, label='Train Data', s=20)
plt.scatter(bmi_test, y_test, label='Test Data', color='red', s=60)

# Add a single line representing the model's predictions for both training and testing data
line_x = np.linspace(min(np.min(bmi_train), np.min(bmi_test)), max(np.max(bmi_train), np.max(bmi_test)), 200)
line_y = slope * line_x + intercept
plt.plot(line_x, line_y, label='Model Line', color='orange', linewidth=2)
plt.show()
